# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a new set of 2,000 random latitudes and longitudes.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
longs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_longs = zip(lats, longs)
lat_longs

# Making a list of coordinates

coord_list = list(lat_longs)

# %%
# Create a list that holds the cities

cities_list = []

# Get the nearest city using the citipy module.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coord_list:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
# Perform an API call with the OpenWeatherMap.

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a24446dbd1170e0d79b0aaf62d2b947a

# %%
# Retrieve the following information from the API call:
    # Latitude and longitude
    # Maximum temperature
    # Percent humidity
    # Percent cloudiness
    # Wind speed
    # Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_des = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_des})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | nisia floresta
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | quipapa
# Processing Record 5 of Set 1 | bratsk
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | margate
# Processing Record 9 of Set 1 | zanjan
# Processing Record 10 of Set 1 | dingle
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | sangar
# Processing Record 17 of Set 1 | inuvik
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | bati
# Processing Record 21 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | watsa
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | tual
# Processing Record 28 of Set 1 | leningradskiy
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | freeport
# Processing Record 32 of Set 1 | hofn
# Processing Record 33 of Set 1 | kununurra
# Processing Record 34 of Set 1 | ancud
# Processing Record 35 of Set 1 | sanmenxia
# Processing Record 36 of Set 1 | severo-kurilsk
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | te anau
# Processing Record 39 of Set 1 | bhanpuri
# Processing Record 40 of Set 1 | cabo san lucas
# Processing Record 41 of Set 1 | sur
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | nichinan
# Processing Record 44 of Set 1 | kavieng
# Processing Record 45 of Set 1 | choix
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | biak
# Processing Record 48 of Set 1 | bambous virieux
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 2 | laje
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | rajec
# Processing Record 4 of Set 2 | lompoc
# Processing Record 5 of Set 2 | umm lajj
# Processing Record 6 of Set 2 | balikpapan
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | fort nelson
# Processing Record 9 of Set 2 | salalah
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | antofagasta
# Processing Record 12 of Set 2 | tilichiki
# Processing Record 13 of Set 2 | matara
# Processing Record 14 of Set 2 | barcelos
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 2 | roth
# Processing Record 18 of Set 2 | panaba
# Processing Record 19 of Set 2 | henties bay
# Processing Record 20 of Set 2 | guerrero negro
# Processing Record 21 of Set 2 | rio brilhante
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | frutigen
# Processing Record 24 of Set 2 | savannah bight
# Processing Record 25 of Set 2 | rikitea
# Processing Record 26 of Set 2 | vao
# Processing Record 27 of Set 2 | kodiak
# Processing Record 28 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 2 | alakurtti
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 2 | ahipara
# Processing Record 33 of Set 2 | chuy
# Processing Record 34 of Set 2 | pevek
# Processing Record 35 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | port-de-bouc
# Processing Record 38 of Set 2 | basco
# Processing Record 39 of Set 2 | shaunavon
# Processing Record 40 of Set 2 | marsabit
# Processing Record 41 of Set 2 | sao joao da barra
# Processing Record 42 of Set 2 | caravelas
# Processing Record 43 of Set 2 | hashtgerd
# Processing Record 44 of Set 2 | port lincoln
# Processing Record 45 of Set 2 | ahuimanu
# Processing Record 46 of Set 2 | barmer
# Processing Record 47 of Set 2 | hurup
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | nemuro
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | tasiilaq
# Processing Record 2 of Set 3 | amapa
# Processing Record 3 of Set 3 | lar gerd
# City not found. Skipping...
# Processing Record 4 of Set 3 | beloha
# Processing Record 5 of Set 3 | port elizabeth
# Processing Record 6 of Set 3 | stephenville
# Processing Record 7 of Set 3 | tuatapere
# Processing Record 8 of Set 3 | kismayo
# Processing Record 9 of Set 3 | bathsheba
# Processing Record 10 of Set 3 | port macquarie
# Processing Record 11 of Set 3 | vardo
# Processing Record 12 of Set 3 | barranca
# Processing Record 13 of Set 3 | khash
# Processing Record 14 of Set 3 | suzu
# City not found. Skipping...
# Processing Record 15 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 3 | barrow
# Processing Record 17 of Set 3 | faanui
# Processing Record 18 of Set 3 | east london
# Processing Record 19 of Set 3 | beira
# Processing Record 20 of Set 3 | arraial do cabo
# Processing Record 21 of Set 3 | porto novo
# Processing Record 22 of Set 3 | upata
# Processing Record 23 of Set 3 | kruisfontein
# Processing Record 24 of Set 3 | komsomolskiy
# Processing Record 25 of Set 3 | qandahar
# City not found. Skipping...
# Processing Record 26 of Set 3 | maragogi
# Processing Record 27 of Set 3 | victoria
# Processing Record 28 of Set 3 | krasnoselkup
# Processing Record 29 of Set 3 | kavaratti
# Processing Record 30 of Set 3 | bras-panon
# Processing Record 31 of Set 3 | vysokogornyy
# Processing Record 32 of Set 3 | mangai
# Processing Record 33 of Set 3 | kalmunai
# Processing Record 34 of Set 3 | camacha
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | torbay
# Processing Record 37 of Set 3 | lata
# Processing Record 38 of Set 3 | klaksvik
# Processing Record 39 of Set 3 | codajas
# Processing Record 40 of Set 3 | capao bonito
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | hambantota
# Processing Record 43 of Set 3 | saint-denis
# Processing Record 44 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 3 | pisco
# Processing Record 46 of Set 3 | bac lieu
# Processing Record 47 of Set 3 | nerchinskiy zavod
# Processing Record 48 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 49 of Set 3 | senanga
# Processing Record 50 of Set 3 | nukus
# Processing Record 1 of Set 4 | puerto del rosario
# Processing Record 2 of Set 4 | saint-joseph
# Processing Record 3 of Set 4 | bethlehem
# Processing Record 4 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 4 | bagamoyo
# Processing Record 6 of Set 4 | chokurdakh
# Processing Record 7 of Set 4 | bredasdorp
# Processing Record 8 of Set 4 | asau
# Processing Record 9 of Set 4 | mizdah
# Processing Record 10 of Set 4 | yumen
# Processing Record 11 of Set 4 | new norfolk
# Processing Record 12 of Set 4 | dryden
# Processing Record 13 of Set 4 | walvis bay
# Processing Record 14 of Set 4 | petrolandia
# City not found. Skipping...
# Processing Record 15 of Set 4 | beni mazar
# Processing Record 16 of Set 4 | rio gallegos
# Processing Record 17 of Set 4 | calabar
# Processing Record 18 of Set 4 | kangaatsiaq
# Processing Record 19 of Set 4 | butaritari
# Processing Record 20 of Set 4 | mount isa
# Processing Record 21 of Set 4 | papara
# Processing Record 22 of Set 4 | aswan
# Processing Record 23 of Set 4 | sajanan
# Processing Record 24 of Set 4 | pingliang
# Processing Record 25 of Set 4 | lakes entrance
# Processing Record 26 of Set 4 | hobyo
# Processing Record 27 of Set 4 | souillac
# Processing Record 28 of Set 4 | bethel
# Processing Record 29 of Set 4 | gizo
# Processing Record 30 of Set 4 | abu samrah
# Processing Record 31 of Set 4 | leh
# Processing Record 32 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 4 | brigantine
# Processing Record 35 of Set 4 | geraldton
# Processing Record 36 of Set 4 | bud
# Processing Record 37 of Set 4 | baykit
# Processing Record 38 of Set 4 | makakilo city
# Processing Record 39 of Set 4 | hilo
# Processing Record 40 of Set 4 | sarakhs
# Processing Record 41 of Set 4 | kieta
# Processing Record 42 of Set 4 | udachnyy
# Processing Record 43 of Set 4 | warri
# Processing Record 44 of Set 4 | ximei
# Processing Record 45 of Set 4 | kjollefjord
# Processing Record 46 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 4 | hastings
# Processing Record 48 of Set 4 | iowa city
# Processing Record 49 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 4 | eureka
# Processing Record 1 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 5 | vila
# Processing Record 3 of Set 5 | georgetown
# Processing Record 4 of Set 5 | cidreira
# Processing Record 5 of Set 5 | aksu
# Processing Record 6 of Set 5 | boguchany
# Processing Record 7 of Set 5 | isangel
# Processing Record 8 of Set 5 | batken
# Processing Record 9 of Set 5 | sao filipe
# Processing Record 10 of Set 5 | poum
# Processing Record 11 of Set 5 | tevaitoa
# Processing Record 12 of Set 5 | luderitz
# Processing Record 13 of Set 5 | katsuura
# Processing Record 14 of Set 5 | port pirie
# Processing Record 15 of Set 5 | kloulklubed
# Processing Record 16 of Set 5 | ketchikan
# Processing Record 17 of Set 5 | dunedin
# Processing Record 18 of Set 5 | halifax
# Processing Record 19 of Set 5 | baracoa
# Processing Record 20 of Set 5 | saint george
# Processing Record 21 of Set 5 | upernavik
# Processing Record 22 of Set 5 | marawi
# Processing Record 23 of Set 5 | belousovka
# Processing Record 24 of Set 5 | huarmey
# Processing Record 25 of Set 5 | cancun
# Processing Record 26 of Set 5 | el alto
# Processing Record 27 of Set 5 | sungaipenuh
# Processing Record 28 of Set 5 | tigil
# Processing Record 29 of Set 5 | castro
# Processing Record 30 of Set 5 | balkanabat
# Processing Record 31 of Set 5 | iralaya
# Processing Record 32 of Set 5 | jumla
# Processing Record 33 of Set 5 | bengkulu
# Processing Record 34 of Set 5 | vanimo
# Processing Record 35 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 5 | kansanshi
# Processing Record 37 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 38 of Set 5 | meulaboh
# Processing Record 39 of Set 5 | cherskiy
# Processing Record 40 of Set 5 | iqaluit
# Processing Record 41 of Set 5 | salinopolis
# Processing Record 42 of Set 5 | louga
# Processing Record 43 of Set 5 | severo-yeniseyskiy
# Processing Record 44 of Set 5 | ust-nera
# Processing Record 45 of Set 5 | talnakh
# Processing Record 46 of Set 5 | flagstaff
# Processing Record 47 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 5 | carlsbad
# Processing Record 49 of Set 5 | tabas
# Processing Record 50 of Set 5 | lasa
# Processing Record 1 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 6 | buritis
# Processing Record 3 of Set 6 | loandjili
# Processing Record 4 of Set 6 | tabou
# Processing Record 5 of Set 6 | touros
# Processing Record 6 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 7 of Set 6 | grand-santi
# Processing Record 8 of Set 6 | camargo
# Processing Record 9 of Set 6 | kargasok
# Processing Record 10 of Set 6 | othonoi
# City not found. Skipping...
# Processing Record 11 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 12 of Set 6 | waipawa
# Processing Record 13 of Set 6 | alofi
# Processing Record 14 of Set 6 | isiro
# Processing Record 15 of Set 6 | cayenne
# Processing Record 16 of Set 6 | glenwood springs
# Processing Record 17 of Set 6 | clyde river
# Processing Record 18 of Set 6 | saldanha
# Processing Record 19 of Set 6 | mahebourg
# Processing Record 20 of Set 6 | zlitan
# Processing Record 21 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 22 of Set 6 | lebu
# Processing Record 23 of Set 6 | longyearbyen
# Processing Record 24 of Set 6 | mao
# Processing Record 25 of Set 6 | paragominas
# Processing Record 26 of Set 6 | port keats
# Processing Record 27 of Set 6 | polovinnoye
# Processing Record 28 of Set 6 | ghauspur
# Processing Record 29 of Set 6 | kulhudhuffushi
# Processing Record 30 of Set 6 | constitucion
# Processing Record 31 of Set 6 | pryamitsyno
# Processing Record 32 of Set 6 | muli
# Processing Record 33 of Set 6 | khatanga
# Processing Record 34 of Set 6 | twin falls
# Processing Record 35 of Set 6 | mount gambier
# Processing Record 36 of Set 6 | jiangyou
# Processing Record 37 of Set 6 | umm kaddadah
# Processing Record 38 of Set 6 | berlevag
# Processing Record 39 of Set 6 | carlet
# Processing Record 40 of Set 6 | nanortalik
# Processing Record 41 of Set 6 | nishihara
# Processing Record 42 of Set 6 | covington
# Processing Record 43 of Set 6 | sterling
# Processing Record 44 of Set 6 | springdale
# Processing Record 45 of Set 6 | ambilobe
# Processing Record 46 of Set 6 | coquimbo
# Processing Record 47 of Set 6 | asfi
# Processing Record 48 of Set 6 | hamilton
# Processing Record 49 of Set 6 | ucluelet
# Processing Record 50 of Set 6 | ilulissat
# Processing Record 1 of Set 7 | chitral
# Processing Record 2 of Set 7 | tomatlan
# Processing Record 3 of Set 7 | fayaoue
# Processing Record 4 of Set 7 | paamiut
# Processing Record 5 of Set 7 | la ronge
# Processing Record 6 of Set 7 | provideniya
# Processing Record 7 of Set 7 | luanda
# Processing Record 8 of Set 7 | kaeo
# Processing Record 9 of Set 7 | usogorsk
# Processing Record 10 of Set 7 | bubaque
# Processing Record 11 of Set 7 | muros
# Processing Record 12 of Set 7 | murud
# Processing Record 13 of Set 7 | jibuti
# Processing Record 14 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 7 | burriana
# Processing Record 16 of Set 7 | knysna
# Processing Record 17 of Set 7 | tanete
# Processing Record 18 of Set 7 | kutum
# Processing Record 19 of Set 7 | bahia de caraquez
# Processing Record 20 of Set 7 | payo
# Processing Record 21 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 7 | yerbogachen
# Processing Record 23 of Set 7 | esna
# Processing Record 24 of Set 7 | raudeberg
# Processing Record 25 of Set 7 | esperance
# Processing Record 26 of Set 7 | arlit
# Processing Record 27 of Set 7 | chengzihe
# Processing Record 28 of Set 7 | riyadh
# Processing Record 29 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 30 of Set 7 | charters towers
# Processing Record 31 of Set 7 | roseburg
# Processing Record 32 of Set 7 | lazaro cardenas
# Processing Record 33 of Set 7 | djambala
# Processing Record 34 of Set 7 | mazatlan
# Processing Record 35 of Set 7 | mehamn
# Processing Record 36 of Set 7 | ilanskiy
# Processing Record 37 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 7 | bafra
# Processing Record 39 of Set 7 | lardos
# Processing Record 40 of Set 7 | san miguel de cauri
# Processing Record 41 of Set 7 | ostersund
# Processing Record 42 of Set 7 | porbandar
# Processing Record 43 of Set 7 | rosarito
# Processing Record 44 of Set 7 | san patricio
# Processing Record 45 of Set 7 | williston
# Processing Record 46 of Set 7 | usakos
# Processing Record 47 of Set 7 | kontagora
# Processing Record 48 of Set 7 | gracac
# Processing Record 49 of Set 7 | polunochnoye
# Processing Record 50 of Set 7 | alindao
# Processing Record 1 of Set 8 | ocampo
# Processing Record 2 of Set 8 | haines junction
# Processing Record 3 of Set 8 | sept-iles
# Processing Record 4 of Set 8 | santa cruz
# Processing Record 5 of Set 8 | vaitape
# Processing Record 6 of Set 8 | la palma
# Processing Record 7 of Set 8 | sorong
# Processing Record 8 of Set 8 | garissa
# Processing Record 9 of Set 8 | irbil
# Processing Record 10 of Set 8 | pirapora
# Processing Record 11 of Set 8 | lorengau
# Processing Record 12 of Set 8 | maumere
# Processing Record 13 of Set 8 | sinnamary
# Processing Record 14 of Set 8 | katsina
# Processing Record 15 of Set 8 | hualmay
# Processing Record 16 of Set 8 | los llanos de aridane
# Processing Record 17 of Set 8 | fukue
# Processing Record 18 of Set 8 | songjianghe
# Processing Record 19 of Set 8 | yarada
# Processing Record 20 of Set 8 | hasaki
# Processing Record 21 of Set 8 | durban
# Processing Record 22 of Set 8 | plettenberg bay
# Processing Record 23 of Set 8 | ust-koksa
# Processing Record 24 of Set 8 | kaitangata
# Processing Record 25 of Set 8 | marsa matruh
# Processing Record 26 of Set 8 | turayf
# Processing Record 27 of Set 8 | mazabuka
# Processing Record 28 of Set 8 | nome
# Processing Record 29 of Set 8 | caraquet
# Processing Record 30 of Set 8 | xambioa
# Processing Record 31 of Set 8 | bani walid
# Processing Record 32 of Set 8 | ulladulla
# Processing Record 33 of Set 8 | bagotville
# Processing Record 34 of Set 8 | loharu
# Processing Record 35 of Set 8 | dali
# Processing Record 36 of Set 8 | araouane
# Processing Record 37 of Set 8 | pleshanovo
# Processing Record 38 of Set 8 | camocim
# Processing Record 39 of Set 8 | dmytrivka
# Processing Record 40 of Set 8 | nizhniy odes
# Processing Record 41 of Set 8 | orlik
# Processing Record 42 of Set 8 | botou
# Processing Record 43 of Set 8 | bagrami
# Processing Record 44 of Set 8 | dukat
# Processing Record 45 of Set 8 | deyang
# Processing Record 46 of Set 8 | madang
# Processing Record 47 of Set 8 | mabaruma
# Processing Record 48 of Set 8 | avera
# Processing Record 49 of Set 8 | ossora
# Processing Record 50 of Set 8 | saint-pierre
# Processing Record 1 of Set 9 | maceio
# Processing Record 2 of Set 9 | salvador
# Processing Record 3 of Set 9 | hanamaki
# Processing Record 4 of Set 9 | coihaique
# Processing Record 5 of Set 9 | chapais
# Processing Record 6 of Set 9 | manzil tamim
# City not found. Skipping...
# Processing Record 7 of Set 9 | kahului
# Processing Record 8 of Set 9 | bridgewater
# Processing Record 9 of Set 9 | bela
# Processing Record 10 of Set 9 | anta
# Processing Record 11 of Set 9 | port shepstone
# Processing Record 12 of Set 9 | barra do garcas
# Processing Record 13 of Set 9 | san quintin
# Processing Record 14 of Set 9 | singkawang
# Processing Record 15 of Set 9 | kudahuvadhoo
# Processing Record 16 of Set 9 | praia
# Processing Record 17 of Set 9 | chipata
# Processing Record 18 of Set 9 | carutapera
# Processing Record 19 of Set 9 | jalu
# Processing Record 20 of Set 9 | ruteng
# Processing Record 21 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 9 | sola
# Processing Record 23 of Set 9 | narovchat
# Processing Record 24 of Set 9 | thaton
# Processing Record 25 of Set 9 | szeged
# Processing Record 26 of Set 9 | dorokhovo
# Processing Record 27 of Set 9 | roma
# Processing Record 28 of Set 9 | sitka
# Processing Record 29 of Set 9 | bowling green
# Processing Record 30 of Set 9 | atambua
# Processing Record 31 of Set 9 | atocha
# Processing Record 32 of Set 9 | turukhansk
# Processing Record 33 of Set 9 | forbes
# Processing Record 34 of Set 9 | akyab
# Processing Record 35 of Set 9 | goure
# Processing Record 36 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 9 | lakatoro
# Processing Record 38 of Set 9 | the valley
# Processing Record 39 of Set 9 | kankaanpaa
# Processing Record 40 of Set 9 | grindavik
# Processing Record 41 of Set 9 | ostrovnoy
# Processing Record 42 of Set 9 | bukachacha
# Processing Record 43 of Set 9 | urusha
# Processing Record 44 of Set 9 | popondetta
# Processing Record 45 of Set 9 | strezhevoy
# Processing Record 46 of Set 9 | porto walter
# Processing Record 47 of Set 9 | duki
# Processing Record 48 of Set 9 | conceicao do araguaia
# Processing Record 49 of Set 9 | sneek
# Processing Record 50 of Set 9 | bocaranga
# City not found. Skipping...
# Processing Record 1 of Set 10 | gunjur
# Processing Record 2 of Set 10 | neiafu
# Processing Record 3 of Set 10 | melilla
# Processing Record 4 of Set 10 | podgorenskiy
# Processing Record 5 of Set 10 | mandera
# Processing Record 6 of Set 10 | moa
# Processing Record 7 of Set 10 | mahibadhoo
# Processing Record 8 of Set 10 | faya
# Processing Record 9 of Set 10 | celestun
# Processing Record 10 of Set 10 | naze
# Processing Record 11 of Set 10 | san gabriel
# Processing Record 12 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 10 | taloqan
# Processing Record 14 of Set 10 | westport
# Processing Record 15 of Set 10 | koslan
# Processing Record 16 of Set 10 | acari
# Processing Record 17 of Set 10 | ribeira grande
# Processing Record 18 of Set 10 | fairbanks
# Processing Record 19 of Set 10 | penzance
# Processing Record 20 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 21 of Set 10 | oum hadjer
# Processing Record 22 of Set 10 | taksimo
# Processing Record 23 of Set 10 | safaga
# Processing Record 24 of Set 10 | gladstone
# Processing Record 25 of Set 10 | izyaslav
# Processing Record 26 of Set 10 | palmer
# Processing Record 27 of Set 10 | flinders
# Processing Record 28 of Set 10 | la macarena
# Processing Record 29 of Set 10 | dikson
# Processing Record 30 of Set 10 | hinton
# Processing Record 31 of Set 10 | bani
# Processing Record 32 of Set 10 | kathu
# Processing Record 33 of Set 10 | puerto carreno
# Processing Record 34 of Set 10 | tursunzoda
# Processing Record 35 of Set 10 | la rioja
# Processing Record 36 of Set 10 | parfino
# Processing Record 37 of Set 10 | dzhebariki-khaya
# Processing Record 38 of Set 10 | severnoye
# Processing Record 39 of Set 10 | merauke
# Processing Record 40 of Set 10 | luganville
# Processing Record 41 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 10 | aljezur
# Processing Record 43 of Set 10 | gravdal
# Processing Record 44 of Set 10 | vila velha
# Processing Record 45 of Set 10 | nagua
# Processing Record 46 of Set 10 | staryy biser
# City not found. Skipping...
# Processing Record 47 of Set 10 | puerto montt
# Processing Record 48 of Set 10 | salym
# Processing Record 49 of Set 10 | adrar
# Processing Record 50 of Set 10 | vanavara
# Processing Record 1 of Set 11 | lagoa
# Processing Record 2 of Set 11 | santa catalina
# Processing Record 3 of Set 11 | monster
# Processing Record 4 of Set 11 | anadyr
# Processing Record 5 of Set 11 | shelburne
# Processing Record 6 of Set 11 | namioka
# Processing Record 7 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 11 | shingu
# Processing Record 9 of Set 11 | lyuban
# Processing Record 10 of Set 11 | hokitika
# Processing Record 11 of Set 11 | unai
# Processing Record 12 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 13 of Set 11 | elko
# Processing Record 14 of Set 11 | zheleznodorozhnyy
# Processing Record 15 of Set 11 | ewa beach
# Processing Record 16 of Set 11 | mogzon
# Processing Record 17 of Set 11 | moose factory
# Processing Record 18 of Set 11 | birin
# Processing Record 19 of Set 11 | megion
# Processing Record 20 of Set 11 | namie
# Processing Record 21 of Set 11 | flin flon
# Processing Record 22 of Set 11 | marrakesh
# Processing Record 23 of Set 11 | marabba
# Processing Record 24 of Set 11 | bambanglipuro
# Processing Record 25 of Set 11 | burnie
# Processing Record 26 of Set 11 | brownfield
# Processing Record 27 of Set 11 | sao gabriel da cachoeira
# Processing Record 28 of Set 11 | nova dubnica
# Processing Record 29 of Set 11 | bilibino
# Processing Record 30 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 11 | ixtapa
# Processing Record 32 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 11 | zapolyarnyy
# Processing Record 34 of Set 11 | spearfish
# Processing Record 35 of Set 11 | adelaide
# Processing Record 36 of Set 11 | nacala
# Processing Record 37 of Set 11 | banda aceh
# Processing Record 38 of Set 11 | tyler
# Processing Record 39 of Set 11 | mushie
# Processing Record 40 of Set 11 | tazovskiy
# Processing Record 41 of Set 11 | antonina
# Processing Record 42 of Set 11 | mahaicony
# City not found. Skipping...
# Processing Record 43 of Set 11 | aykhal
# Processing Record 44 of Set 11 | kalevala
# Processing Record 45 of Set 11 | hovd
# Processing Record 46 of Set 11 | youghal
# Processing Record 47 of Set 11 | atar
# Processing Record 48 of Set 11 | chemal
# Processing Record 49 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 50 of Set 11 | caibarien
# Processing Record 1 of Set 12 | portland
# Processing Record 2 of Set 12 | bereda
# Processing Record 3 of Set 12 | montecristo
# Processing Record 4 of Set 12 | qasigiannguit
# Processing Record 5 of Set 12 | presidencia roque saenz pena
# Processing Record 6 of Set 12 | goderich
# Processing Record 7 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 8 of Set 12 | loiza
# Processing Record 9 of Set 12 | sampit
# Processing Record 10 of Set 12 | tautira
# Processing Record 11 of Set 12 | vung tau
# Processing Record 12 of Set 12 | yar-sale
# Processing Record 13 of Set 12 | altay
# Processing Record 14 of Set 12 | muisne
# Processing Record 15 of Set 12 | korba
# Processing Record 16 of Set 12 | cairns
# Processing Record 17 of Set 12 | lavrentiya
# Processing Record 18 of Set 12 | mecca
# Processing Record 19 of Set 12 | esmeraldas
# Processing Record 20 of Set 12 | tombouctou
# Processing Record 21 of Set 12 | panjakent
# Processing Record 22 of Set 12 | sambava
# Processing Record 23 of Set 12 | verkhoyansk
# Processing Record 24 of Set 12 | gushikawa
# Processing Record 25 of Set 12 | vestmanna
# Processing Record 26 of Set 12 | narsaq
# Processing Record 27 of Set 12 | padang
# Processing Record 28 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 12 | san andres
# Processing Record 30 of Set 12 | gibara
# Processing Record 31 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 12 | olavarria
# Processing Record 33 of Set 12 | antalaha
# Processing Record 34 of Set 12 | karlstad
# Processing Record 35 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 36 of Set 12 | bunia
# Processing Record 37 of Set 12 | beringovskiy
# Processing Record 38 of Set 12 | olinda
# Processing Record 39 of Set 12 | port hardy
# Processing Record 40 of Set 12 | brighton
# Processing Record 41 of Set 12 | queenstown
# Processing Record 42 of Set 12 | ishurdi
# Processing Record 43 of Set 12 | yeppoon
# Processing Record 44 of Set 12 | krasnyy yar
# Processing Record 45 of Set 12 | husavik
# Processing Record 46 of Set 12 | loa janan
# Processing Record 47 of Set 12 | ola
# Processing Record 48 of Set 12 | ust-ilimsk
# Processing Record 49 of Set 12 | dwarka
# Processing Record 50 of Set 12 | codrington
# Processing Record 1 of Set 13 | san cristobal
# Processing Record 2 of Set 13 | muncar
# Processing Record 3 of Set 13 | long beach
# Processing Record 4 of Set 13 | vega de alatorre
# Processing Record 5 of Set 13 | tecoanapa
# Processing Record 6 of Set 13 | merrill
# Processing Record 7 of Set 13 | bella vista
# Processing Record 8 of Set 13 | yantal
# Processing Record 9 of Set 13 | susanville
# Processing Record 10 of Set 13 | patacamaya
# Processing Record 11 of Set 13 | glauchau
# Processing Record 12 of Set 13 | grenfell
# Processing Record 13 of Set 13 | san rafael
# Processing Record 14 of Set 13 | luhacovice
# Processing Record 15 of Set 13 | gigmoto
# Processing Record 16 of Set 13 | north platte
# Processing Record 17 of Set 13 | yatou
# Processing Record 18 of Set 13 | coron
# Processing Record 19 of Set 13 | hohhot
# Processing Record 20 of Set 13 | teknaf
# Processing Record 21 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 22 of Set 13 | alyangula
# Processing Record 23 of Set 13 | miandrivazo
# Processing Record 24 of Set 13 | kimbe
# Processing Record 25 of Set 13 | ilebo
# Processing Record 26 of Set 13 | cabedelo
# Processing Record 27 of Set 13 | candelaria
# Processing Record 28 of Set 13 | bo rai
# Processing Record 29 of Set 13 | boende
# Processing Record 30 of Set 13 | golden
# Processing Record 31 of Set 13 | zhigansk
# Processing Record 32 of Set 13 | kedrovyy
# Processing Record 33 of Set 13 | awjilah
# Processing Record 34 of Set 13 | gornyy
# Processing Record 35 of Set 13 | hamburg
# Processing Record 36 of Set 13 | necochea
# Processing Record 37 of Set 13 | catamarca
# Processing Record 38 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 39 of Set 13 | fortuna
# Processing Record 40 of Set 13 | hilton head island
# Processing Record 41 of Set 13 | batagay-alyta
# Processing Record 42 of Set 13 | laguna
# Processing Record 43 of Set 13 | sorland
# Processing Record 44 of Set 13 | mayo
# Processing Record 45 of Set 13 | maltahohe
# Processing Record 46 of Set 13 | saint-augustin
# Processing Record 47 of Set 13 | ternate
# Processing Record 48 of Set 13 | saint anthony
# Processing Record 49 of Set 13 | pangnirtung
# Processing Record 50 of Set 13 | whitehorse
# Processing Record 1 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 2 of Set 14 | axim
# Processing Record 3 of Set 14 | parakan
# Processing Record 4 of Set 14 | grand-lahou
# Processing Record 5 of Set 14 | ilawa
# Processing Record 6 of Set 14 | hervey bay
# Processing Record 7 of Set 14 | jackson
# Processing Record 8 of Set 14 | port augusta
# Processing Record 9 of Set 14 | ballitoville
# Processing Record 10 of Set 14 | santiago del estero
# Processing Record 11 of Set 14 | okandja
# City not found. Skipping...
# Processing Record 12 of Set 14 | alice springs
# Processing Record 13 of Set 14 | bebra
# Processing Record 14 of Set 14 | benguela
# Processing Record 15 of Set 14 | boueni
# Processing Record 16 of Set 14 | senekal
# Processing Record 17 of Set 14 | honiara
# Processing Record 18 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 19 of Set 14 | port hedland
# Processing Record 20 of Set 14 | vostok
# Processing Record 21 of Set 14 | semenivka
# Processing Record 22 of Set 14 | trelew
# Processing Record 23 of Set 14 | kijang
# Processing Record 24 of Set 14 | abnub
# Processing Record 25 of Set 14 | kalomo
# City not found. Skipping...
# Processing Record 26 of Set 14 | mulege
# Processing Record 27 of Set 14 | saint-louis
# Processing Record 28 of Set 14 | segovia
# Processing Record 29 of Set 14 | medea
# Processing Record 30 of Set 14 | acandi
# Processing Record 31 of Set 14 | xichang
# Processing Record 32 of Set 14 | visegrad
# Processing Record 33 of Set 14 | karratha
# Processing Record 34 of Set 14 | kharp
# Processing Record 35 of Set 14 | ponferrada
# Processing Record 36 of Set 14 | acarau
# Processing Record 37 of Set 14 | mizan teferi
# Processing Record 38 of Set 14 | tonantins
# Processing Record 39 of Set 14 | paris
# Processing Record 40 of Set 14 | inhambane
# Processing Record 41 of Set 14 | syntul
# Processing Record 42 of Set 14 | frontera
# Processing Record 43 of Set 14 | honningsvag
# Processing Record 44 of Set 14 | alexandria
# Processing Record 45 of Set 14 | colac
# Processing Record 46 of Set 14 | humboldt
# Processing Record 47 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 48 of Set 14 | ulaanbaatar
# Processing Record 49 of Set 14 | yulara
# Processing Record 50 of Set 14 | gilbues
# Processing Record 1 of Set 15 | bundaberg
# Processing Record 2 of Set 15 | canon city
# Processing Record 3 of Set 15 | zhanaozen
# Processing Record 4 of Set 15 | natal
# Processing Record 5 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 15 | rawson
# Processing Record 7 of Set 15 | jian
# Processing Record 8 of Set 15 | tambacounda
# Processing Record 9 of Set 15 | nacozari
# Processing Record 10 of Set 15 | aquidauana
# Processing Record 11 of Set 15 | arman
# Processing Record 12 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 15 | cacapava do sul
# Processing Record 14 of Set 15 | ust-kuyga
# Processing Record 15 of Set 15 | boden
# Processing Record 16 of Set 15 | seoul
# Processing Record 17 of Set 15 | kardasova recice
# Processing Record 18 of Set 15 | nouakchott
# Processing Record 19 of Set 15 | clovis
# Processing Record 20 of Set 15 | srandakan
# Processing Record 21 of Set 15 | puerto el triunfo
# Processing Record 22 of Set 15 | menzelinsk
# Processing Record 23 of Set 15 | sredec
# City not found. Skipping...
# Processing Record 24 of Set 15 | imbituba
# Processing Record 25 of Set 15 | namibe
# Processing Record 26 of Set 15 | rosetown
# Processing Record 27 of Set 15 | anaconda
# Processing Record 28 of Set 15 | cuamba
# Processing Record 29 of Set 15 | filadelfia
# Processing Record 30 of Set 15 | waingapu
# Processing Record 31 of Set 15 | hami
# Processing Record 32 of Set 15 | anloga
# Processing Record 33 of Set 15 | corni
# Processing Record 34 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 15 | angoche
# Processing Record 36 of Set 15 | vila franca do campo
# Processing Record 37 of Set 15 | ukiah
# Processing Record 38 of Set 15 | shimoda
# Processing Record 39 of Set 15 | kodinsk
# Processing Record 40 of Set 15 | manacapuru
# Processing Record 41 of Set 15 | tessalit
# Processing Record 42 of Set 15 | russell
# Processing Record 43 of Set 15 | fairborn
# Processing Record 44 of Set 15 | namatanai
# Processing Record 45 of Set 15 | biograd na moru
# Processing Record 46 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 15 | santa ines
# Processing Record 48 of Set 15 | homer
# Processing Record 49 of Set 15 | ouallam
# Processing Record 50 of Set 15 | kadirli
# Processing Record 1 of Set 16 | miraflores
# Processing Record 2 of Set 16 | kindu
# Processing Record 3 of Set 16 | zakamensk
# Processing Record 4 of Set 16 | alberton
# Processing Record 5 of Set 16 | camopi
# Processing Record 6 of Set 16 | sao felix do xingu
# Processing Record 7 of Set 16 | sokolow podlaski
# Processing Record 8 of Set 16 | ramban
# Processing Record 9 of Set 16 | tarakan
# Processing Record 10 of Set 16 | nizhniy kuranakh
# Processing Record 11 of Set 16 | pochutla
# Processing Record 12 of Set 16 | manokwari
# Processing Record 13 of Set 16 | bowen
# Processing Record 14 of Set 16 | gilgit
# Processing Record 15 of Set 16 | cam ranh
# Processing Record 16 of Set 16 | birjand
# Processing Record 17 of Set 16 | montebello
# Processing Record 18 of Set 16 | kirkland lake
# Processing Record 19 of Set 16 | gold coast
# Processing Record 20 of Set 16 | oussouye
# Processing Record 21 of Set 16 | uhlove
# Processing Record 22 of Set 16 | richards bay
# Processing Record 23 of Set 16 | shirokiy
# Processing Record 24 of Set 16 | behbahan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas      CL -53.1500  -70.9167     50.11        34           0
# 1  Nisia Floresta      BR  -6.0911  -35.2086     79.43        78           6
# 2       Jamestown      US  42.0970  -79.2353     42.39        50           1
# 3         Quipapa      BR  -8.8278  -36.0117     72.43        86          24
# 4          Bratsk      RU  56.1325  101.6142      5.49        94         100
# 5           Bluff      NZ -46.6000  168.3333     61.81        71          26
# 6     Yellowknife      CA  62.4560 -114.3525      9.41        91         100
# 7         Margate      GB  51.3813    1.3862     53.31        84          99
# 8          Zanjan      IR  36.6736   48.4787     37.87        57           0
# 9          Dingle      PH  10.9995  122.6711     75.34        92          92
#
#    Wind Speed Current Description
# 0       23.02           clear sky
# 1       10.56           clear sky
# 2        8.99           clear sky
# 3       10.71          few clouds
# 4        5.53     overcast clouds
# 5        4.76    scattered clouds
# 6        5.99     overcast clouds
# 7        4.00     overcast clouds
# 8        2.51           clear sky
# 9        7.99     overcast clouds

# %%
# Export the DataFrame as a CSV file

# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
